# %% [markdown]
# **DATA CLEANING AND SVM(Support Vector Machine)**
#
# ---

# %% [markdown]
# **1.DATA CLEANING USING**
# *   Minimal Value Replacement
# *   Interpolation

# %%
#CLEANING
import pandas as pd

# Load your dataset (replace 'your_dataset.csv' with your actual file name)
df = pd.read_csv('/content/dataset.csv')

# Replace NaN values with 0.0001
df_filled = df.fillna(0.0001)

# Replace zero values with 0.0001
df_filled = df_filled.replace(0, 0.0001)

# Save the modified dataset (replace 'modified_dataset.csv' with your desired file name)
df_filled.to_csv('modified_dataset.csv', index=False)

# %% [markdown]
# **DOWNLOADING CLEANED DATA**

# %%
from google.colab import files

# Specify the file path
file_path = 'modified_dataset.csv'  # Replace this with the path to your cleaned dataset

# Download the file
files.download(file_path)

# %% [markdown]
# **2. APPLYING SVM ON CLOF CLUSTERED DATA**
#
#    **Output -**
#
# 1.   Improved Accuracy
# 2.   Improved Precision
# 1.   Improved Recall
# 2.   Improved F1 Score
# 2.   Improved ROC Curve with visual

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Load your dataset (replace with actual path)
data = pd.read_csv("/content/P-clof outliers for further improvement.csv")

# Handle missing values (e.g., imputation or removal)
# ...

# Encode categorical features (if applicable)
# ...

# Scale features (if applicable)
scaler = StandardScaler().fit(data[["Rank", "Principal Component 1", "Principal Component 2"]])
X_scaled = scaler.transform(data[["Rank", "Principal Component 1", "Principal Component 2"]])

# Separate features (X) and target variable (y)
X = X_scaled
y = data["FLAG"]



    # Add legend for "theft" and "non-theft" classes
    handles = [plt.Line2D([], [], marker="o", markersize=10, color='w', markerfacecolor='orange', label='Theft'),
               plt.Line2D([], [], marker="o", markersize=10, color='w', markerfacecolor='blue', label='Non-Theft')]
    plt.legend(handles=handles)

    plt.show()
else:
    print("Visualization not possible for features with more than 2 dimensions.")
# Out:
# Accuracy: 92.5925925925926
# Precision: 95.55555555555556
# Recall: 91.48936170212765
# F1-score: 93.47826086956522
# ROC AUC: 92.80350438047559
# Visualization not possible for features with more than 2 dimensions.
# Visualization not possible for features with more than 2 dimensions.
